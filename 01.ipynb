# %% [markdown]
# <h1 style="color: orange;">Условие 2:</h1>

# %% [markdown]
# На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и их количество, а возвращает общее количество фруктов на складе

# %%
def total_fruits(*args):
    total = 0
    for count in args:
        total += count
    return total


fruits = {
    'яблоки': 10,
    'бананы': 5,
    'груши': 8,
    'апельсины': 12
}

fruits_count = total_fruits(*fruits.values())
print(f"Общее количество фруктов на складе: {fruits_count}")
# Out:
# Общее количество фруктов на складе: 35

# %% [markdown]
# <h1 style="color: orange;">Условие 3:</h1>

# %% [markdown]
# Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты
# [100, 125, -90, 345, 655, -1, 0, 200]
# Используйте list comprehensions

# %%
costs = [100, 125, -90, 345, 655, -1, 0, 200]
verified_costs = [i for i in costs if i >= 0 ]
print(verified_costs)
print(f'Totol costs: {sum(verified_costs)} rub.')
# Out:
# [100, 125, 345, 655, 0, 200]
# Totol costs: 1425 rub.

# %% [markdown]
# <h1 style="color: orange;">Условие 4.1:</h1>

# %% [markdown]
# Даны два списка.
# Дата покупки
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
# Суммы покупок по датам
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#  Найдите, какая выручка у компании в ноябре
# Используйте list comprehensions

# %%
date = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30',
         '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18',
           '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20',
             '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09',
               '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']

revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037,
            4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008,
              316, 6333, 5700, 2887]
november_revenue = [revenue[i] for i, d in  enumerate(date) if '-11-' in d]
print(november_revenue)
print(f'November revenue : {sum(november_revenue)} RUB')
# Out:
# [4944, 3701, 7037, 4274, 2004, 2822, 316]
# November revenue : 25098 RUB

# %% [markdown]
# <h1 style="color: orange;">Условие 4.2:</h1>

# %% [markdown]
# 4.2 Найдите выручку компании в зависимости от месяца
# Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.
# Используйте аннотирование типов.

# %%
date = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30',
        '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18',
        '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20',
        '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09',
        '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']

revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037,
           4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008,
           316, 6333, 5700, 2887]


def monthlyRevenue(date: list, revenue: list) -> dict:
    total = {}
    months = {'-01-': 'январь', '-02-': 'февраль', '-03-': 'март', '-04-': 'апрель', '-05-': 'май',
              '-06-': 'июнь', '-07-': 'июль', '-08-': 'август', '-09-': 'сентябрь', '-10-': 'октябрь',
              '-11-': 'ноябрь', '-12-': 'декабрь'}
    for month in months.keys():
        sum = 0
        for j, d in enumerate(date):
            if month in d:
                sum = sum + revenue[j]
        total[months[month]] = sum
    return total


result_dict = monthlyRevenue(date, revenue)
for month, total_revenue in result_dict.items():
    print(month, ':', total_revenue, 'руб.')
# Out:
# январь : 0 руб.
# февраль : 0 руб.
# март : 0 руб.
# апрель : 0 руб.
# май : 0 руб.
# июнь : 0 руб.
# июль : 0 руб.
# август : 0 руб.
# сентябрь : 25647 руб.
# октябрь : 28645 руб.
# ноябрь : 25098 руб.
# декабрь : 45452 руб.
